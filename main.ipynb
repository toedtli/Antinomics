# %%
# %matplotlib qt

# %%
# %load_ext autoreload

# %autoreload 2

# %%
import mne
fname = "/Users/milenaengelke/tmp/data_in/50031/EEG/rest/50031_restingstate.vhdr"
raw = mne.io.read_raw_brainvision(fname)
events, ids = mne.events_from_annotations(raw)
# Out:
# Extracting parameters from /Users/milenaengelke/tmp/data_in/50031/EEG/rest/50031_restingstate.vhdr...
# Setting channel info structure...
# Used Annotations descriptions: [np.str_('New Segment/')]
# /var/folders/zt/xwt9j1j963lbn6mcrnf17v4h0000gn/T/ipykernel_10463/3253102622.py:3: RuntimeWarning: No coordinate information found for channels ['audio']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   raw = mne.io.read_raw_brainvision(fname)
# /var/folders/zt/xwt9j1j963lbn6mcrnf17v4h0000gn/T/ipykernel_10463/3253102622.py:3: RuntimeWarning: Not setting position of 1 misc channel found in montage:
# ['audio']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne.io.read_raw_brainvision(fname)

# %%
# %matplotlib qt
fname = "/Users/milenaengelke/tmp/data_in/50031/EEG/rest/50031_restingstate.vhdr"
sub_dir = "/Users/milenaengelke/tmp/data_in/50031/EEG"
subject_id = "50031"
site = "Regensburg"
from preprocess import preprocess
preprocess(fname=fname, subject_id=subject_id,
            subjects_dir=sub_dir,
            site=site,
            paradigm="rest")
# Out:
#  20%|█████████
# Finding and reading raw EEG data ...
# /Users/milenaengelke/TIDE/Antinomics_payam/eeg/eeg_preprocessing.py:246: UserWarning: The preprocessed raw /Users/milenaengelke/tmp/data_in/50031/EEG/50031/orig/raw_rest.fif already exist.
#   warn(f"The preprocessed raw {orig_fname} already exist.")
#  40%|██████████████████
# Resampling, filtering and re-referencing ...
# 2025-04-22 15:43:38.096 python[10463:312218] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-04-22 15:43:38.210 python[10463:312218] +[IMKInputSession subclass]: chose IMKInputSession_Modern
#  60%|███████████████████████████
# Running ICA ...
#
# Not setting metadata
# 171 matching events found
# No baseline correction applied
# 0 projection items activated
# Not setting metadata
# 171 matching events found
# No baseline correction applied
# 0 projection items activated
#  80%|████████████████████████████████████
# Creating report and saving...
# /Users/milenaengelke/TIDE/Antinomics_payam/eeg/eeg_preprocessing.py:428: UserWarning: The preprocessed raw /Users/milenaengelke/tmp/data_in/50031/EEG/50031/preprocessed/raw_rest.fif already exist.
#   warn(f"The preprocessed raw {prep_fname} already exist.")
# 100%|█████████████████████████████████████████████
# EEG data were preprocessed sucessfully!

# %%
from eeg import preprocessing
preprocessing(subject_id=subject_id,
                subjects_dir=sub_dir,
                paradigm="rest",
                site=site,
                psd_check=True,
                manual_data_scroll=True,
                run_ica=False,
                manual_ica_removal=False,
                ssp_eog=True,
                ssp_ecg=True,
                create_report=True,
                saving_dir=None,
                verbose="ERROR")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from eeg import preprocessing
#       2 preprocessing(subject_id="50031",
#       3                 subjects_dir="/Users/payamsadeghishabestari/antinomics_clean_codes/subjects",
#       4                 paradigm="rest",
#    (...)
#      13                 saving_dir=None,
#      14                 verbose="ERROR")
#
# ImportError: cannot import name 'preprocessing' from 'eeg' (/Users/milenaengelke/TIDE/Antinomics_payam/eeg/__init__.py)

# %%
# %matplotlib qt
from eeg.eeg_processing import run_rs_analysis
run_rs_analysis(
        subject_id=subject_id,
        subjects_dir=sub_dir,
        site=site,
        visit=1,
        event_ids=None,
        source_analysis=True,
        subjects_fs_dir=None,
        manual_data_scroll=True,
        automatic_epoch_rejection=False,
        create_report=True,
        saving_dir=None,
        verbose="ERROR",
        config_file="eeg/preprocessing-config.yaml"
        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 get_ipython().run_line_magic('matplotlib', 'qt')
#       2 from eeg.eeg_processing import run_rs_analysis
# ----> 3 run_rs_analysis(
#       4         subject_id=subject_id,
#       5         subjects_dir=sub_dir,
#       6         site=site,
#       7         visit=1,
#       8         event_ids=None,
#       9         source_analysis=True,
#      10         subjects_fs_dir=None,
#      11         manual_data_scroll=True,
#      12         automatic_epoch_rejection=False,
#      13         create_report=True,
#      14         saving_dir=None,
#      15         verbose="ERROR",
#      16         config_file="eeg/preprocessing-config.yaml"
#      17         )
#
# File ~/TIDE/Antinomics_payam/eeg/eeg_processing.py:107, in run_rs_analysis(subject_id, site, subjects_dir, overwrite, config_file, **kwargs)
#     104 verbose = config.get("verbose", "ERROR")
#     106 set_log_level(verbose=verbose)
# --> 107 total = 10 if mri else 8
#     108 progress = tqdm(total=total,
#     109                 desc="",
#     110                 ncols=50,
#     111                 colour="cyan",
#     112                 bar_format='{l_bar}{bar}'
#     113                 )
#     115 time.sleep(1)
#
# NameError: name 'mri' is not defined

# %%
# %matplotlib qt
from eeg_processing import run_erp_analysis
run_erp_analysis(
        subject_id="zdfy",
        subjects_dir="/Users/payamsadeghishabestari/antinomics_clean_codes/subjects",
        paradigm="gpias",
        events=None,
        source_analysis=True,
        mri=False,
        subjects_fs_dir=None,
        manual_data_scroll=True,
        automatic_epoch_rejection=False,
        create_report=True,
        saving_dir=None,
        verbose="ERROR"
        )

# %% [markdown]
# Eyetracking

# %%
from mne.io import read_raw_brainvision, read_raw_eyelink
from mne import events_from_annotations
from mne.preprocessing import realign_raw


## load
fname_eeg = "/Users/payamsadeghishabestari/Downloads/alertness_01_H036.vhdr"
fname_et = "/Users/payamsadeghishabestari/Downloads/local_al1H036.asc"

raw_eeg = read_raw_brainvision(fname_eeg, preload=True)
raw_eye = read_raw_eyelink(fname=fname_et, create_annotations=True) 
events_eeg, event_ids_eeg = events_from_annotations(raw_eeg)
events_eye, event_ids_eye = events_from_annotations(raw_eye)

## for now
stim_id_eeg_1, stim_id_eeg_2 = 8, 9
stim_id_eye_1, stim_id_eye_2 = 4, 5

s_raw = events_eeg[(events_eeg[:,2] == stim_id_eeg_1) | (events_eeg[:,2] == stim_id_eeg_2)][:, 0]
s_other = events_eye[(events_eye[:,2] == stim_id_eye_1) | (events_eye[:,2] == stim_id_eye_2)][:, 0]

## realigning
realign_raw(raw=raw_eeg,
            other=raw_eye,
            t_raw=s_raw / raw_eeg.info["sfreq"] - raw_eeg.first_time,
            t_other=s_other / raw_eye.info["sfreq"] - raw_eye.first_time,
            verbose=None)

raw_eye.add_channels([raw_eeg], force_update_info=True)
events, event_dict = events_from_annotations(raw_eye)
del raw_eeg

# %%
raw_eye.plot()

# %% [markdown]
# Lets see what is regularity

# %%
import mne

# %%
fname = "/Users/payamsadeghishabestari/antinomics_clean_codes/subjects/dvob/EEG/regularity/dvob_regularity.vhdr"
raw = mne.io.read_raw_brainvision(fname, preload=True)
raw.resample(250)

# %%
events, events_dict = mne.events_from_annotations(raw)

# %%
import mne
epochs_fnames = ["/Users/payamsadeghishabestari/antinomics_clean_codes/subjects/zdfy/EEG/rest_v1/epochs-eo-epo.fif",
                "/Users/payamsadeghishabestari/antinomics_clean_codes/subjects/zdfy/EEG/rest_v1/epochs-ec-epo.fif"]

epochs, eye_labels = [], []
for ep_fname, title in zip(epochs_fnames, ["open", "close"]):
    eps = mne.read_epochs(ep_fname, preload=True)
    eps.drop_bad()
    epochs.append(eps)
    eye_labels += len(eps) * [title]

# %%
epochs = mne.concatenate_epochs(epochs)

# %%
import numpy as np
import mne_features

# %%
def compute_sensor_band_power(epochs):
    """
    """
    freq_bands = {
                    "delta": (0.5, 4),
                    "theta": (4, 8),
                    "alpha": (8, 13),
                    "beta": (13, 30),
                    "lower_gamma": (30, 45),
                    "upper_gamma": (45, 80)
                    }
    
    psds, freqs = epochs.compute_psd(method="multitaper",
                                    picks="eeg",
                                    fmin=freq_bands["delta"][0],
                                    fmax=freq_bands["upper_gamma"][1],
                                    ).get_data(return_freqs=True)
    psds /= np.sum(psds, axis=-1, keepdims=True)  # normalize the PSDs
    ep_psds = []
    for fmin, fmax in freq_bands.values():
        psds_band = psds[:, :, (freqs >= fmin) & (freqs < fmax)].mean(axis=-1)
        ep_psds.append(psds_band)
    

    return np.array(ep_psds).transpose(1, 2, 0)

# %%
freq_bands = {
                "delta": (0.5, 4),
                "theta": (4, 8),
                "alpha": (8, 13),
                "beta": (13, 30),
                "lower_gamma": (30, 45),
                "upper_gamma": (45, 80)
                }



epochs.pick("eeg")
funcs_params = {
                    "pow_freq_bands__freq_bands": freq_bands,
                    "pow_freq_bands__psd_method": "multitaper",
                    "pow_freq_bands__normalize": True
                    } 

powers = mne_features.feature_extraction.extract_features(epochs.get_data(),
                                                epochs.info["sfreq"],
                                                selected_funcs=["pow_freq_bands"],
                                                funcs_params=funcs_params,
                                                ch_names=epochs.info["ch_names"]
                                                )

# %%
n_chs = len(epochs.info["ch_names"])
n_freq_bands = len(freq_bands.keys())
powers_reshaped = powers.reshape(len(epochs), n_chs, n_freq_bands)

# %%
columns = [f"ch_{j}_freq_{k}" for j in epochs.info["ch_names"] for k in freq_bands]

# %%
df = pd.DataFrame(powers_reshaped, columns=columns)

# %%
hurst = mne_features.feature_extraction.extract_features(epochs.get_data(),
                                                epochs.info["sfreq"],
                                                selected_funcs=["spect_slope"],
                                                funcs_params=None,
                                                ch_names=epochs.info["ch_names"]
                                                )

# %%
y = hurst.reshape(len(epochs), n_chs, 4)[:,:,:2] # intercept and slope

# %%
y.shape

# %%
x = hurst.reshape(len(epochs), n_chs, 4)[:,:,:2]

# %%
x = x.reshape(257, 118)

# %%
x == hurst[:, :118]

# %%
freq_bands = {
            "delta": (0.5, 4),
            "theta": (4, 8),
            "alpha": (8, 13),
            "beta": (13, 30),
            "lower_gamma": (30, 45),
            "upper_gamma": (45, 80)
            }

psds, freqs = epochs.compute_psd(method="multitaper",
                                    picks="eeg",
                                    fmin=freq_bands["delta"][0],
                                    fmax=freq_bands["upper_gamma"][1],
                                    ).get_data(return_freqs=True)

# %%
psds.shape

# %%
X

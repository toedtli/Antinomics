# %%
# %matplotlib qt

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/50001/EEG/rest"
# Out:
# 50001_restingstate.eeg	 50001_restingstate.vmrk  operator-inv.fif
# 50001_restingstate.vhdr  epochs-eo-epo.fif	  raw_prep.fif

# %%
# !pip install -r "/content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt"
# Out:
# Collecting appnope==0.1.4 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 1))
#   Downloading appnope-0.1.4-py2.py3-none-any.whl.metadata (908 bytes)
# Collecting asttokens==3.0.0 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 2))
#   Downloading asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting autoreject==0.4.3 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 3))
#   Downloading autoreject-0.4.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: certifi==2025.1.31 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 4)) (2025.1.31)
# Requirement already satisfied: charset-normalizer==3.4.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 5)) (3.4.1)
# Collecting comm==0.2.2 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 6))
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: contourpy==1.3.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 7)) (1.3.2)
# Requirement already satisfied: cycler==0.12.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 8)) (0.12.1)
# Collecting darkdetect==0.8.0 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 9))
#   Downloading darkdetect-0.8.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting debugpy==1.8.14 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 10))
#   Downloading debugpy-1.8.14-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting decorator==5.2.1 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 11))
#   Downloading decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting exceptiongroup==1.2.2 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 12))
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting executing==2.2.0 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 13))
#   Downloading executing-2.2.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: fonttools==4.57.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 14)) (4.57.0)
# Collecting h5io==0.2.5 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 15))
#   Downloading h5io-0.2.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: h5py==3.13.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 16)) (3.13.0)
# Requirement already satisfied: idna==3.10 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 17)) (3.10)
# Requirement already satisfied: importlib_resources==6.5.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 18)) (6.5.2)
# Collecting ipykernel==6.29.5 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 19))
#   Downloading ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting ipython==8.35.0 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 20))
#   Downloading ipython-8.35.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting jedi==0.19.2 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 21))
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: Jinja2==3.1.6 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 22)) (3.1.6)
# Requirement already satisfied: joblib==1.4.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 23)) (1.4.2)
# Collecting jupyter_client==8.6.3 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 24))
#   Downloading jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: jupyter_core==5.7.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 25)) (5.7.2)
# Requirement already satisfied: kiwisolver==1.4.8 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 26)) (1.4.8)
# Requirement already satisfied: lazy_loader==0.4 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 27)) (0.4)
# Collecting llvmlite==0.44.0 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 28))
#   Downloading llvmlite-0.44.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: MarkupSafe==3.0.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 29)) (3.0.2)
# Collecting matplotlib==3.10.1 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 30))
#   Downloading matplotlib-3.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: matplotlib-inline==0.1.7 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 31)) (0.1.7)
# Collecting mne==1.9.0 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 32))
#   Downloading mne-1.9.0-py3-none-any.whl.metadata (20 kB)
# Collecting mne-features==0.3 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 33))
#   Downloading mne_features-0.3-py3-none-any.whl.metadata (2.6 kB)
# Collecting mne-icalabel==0.7.0 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 34))
#   Downloading mne_icalabel-0.7.0-py3-none-any.whl.metadata (10 kB)
# Collecting mne-qt-browser==0.7.1 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 35))
#   Downloading mne_qt_browser-0.7.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: nest-asyncio==1.6.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 36)) (1.6.0)
# Requirement already satisfied: nibabel==5.3.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 37)) (5.3.2)
# Collecting numba==0.61.2 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 38))
#   Downloading numba-0.61.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting numpy==2.2.4 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 39))
#   Downloading numpy-2.2.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging==24.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 40)) (24.2)
# Collecting pandas==2.2.3 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 41))
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: parso==0.8.4 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 42)) (0.8.4)
# Requirement already satisfied: pexpect==4.9.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 43)) (4.9.0)
# Collecting pillow==11.2.1 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 44))
#   Downloading pillow-11.2.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Requirement already satisfied: platformdirs==4.3.7 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 45)) (4.3.7)
# Requirement already satisfied: pooch==1.8.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 46)) (1.8.2)
# Requirement already satisfied: prompt_toolkit==3.0.51 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 47)) (3.0.51)
# Collecting psutil==7.0.0 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 48))
#   Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: ptyprocess==0.7.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 49)) (0.7.0)
# Collecting pure_eval==0.2.3 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 50))
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting Pygments==2.19.1 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 51))
#   Downloading pygments-2.19.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting pymatreader==1.0.0 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 52))
#   Downloading pymatreader-1.0.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: PyOpenGL==3.1.9 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 53)) (3.1.9)
# Collecting PyOpenGL-accelerate==3.1.9 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 54))
#   Downloading PyOpenGL_accelerate-3.1.9-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: pyparsing==3.2.3 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 55)) (3.2.3)
# Collecting PyQt6==6.9.0 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 56))
#   Downloading PyQt6-6.9.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Collecting PyQt6-Qt6==6.9.0 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 57))
#   Downloading PyQt6_Qt6-6.9.0-py3-none-manylinux_2_28_x86_64.whl.metadata (534 bytes)
# Collecting PyQt6_sip==13.10.0 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 58))
#   Downloading PyQt6_sip-13.10.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (472 bytes)
# Collecting pyqtgraph==0.13.7 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 59))
#   Downloading pyqtgraph-0.13.7-py3-none-any.whl.metadata (1.3 kB)
# Collecting pyriemann==0.8 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 60))
#   Downloading pyriemann-0.8-py2.py3-none-any.whl.metadata (9.3 kB)
# Collecting python-dateutil==2.9.0.post0 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 61))
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: pytz==2025.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 62)) (2025.2)
# Collecting PyWavelets==1.8.0 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 63))
#   Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: PyYAML==6.0.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 64)) (6.0.2)
# Collecting pyzmq==26.4.0 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 65))
#   Downloading pyzmq-26.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# Collecting QDarkStyle==3.2.3 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 66))
#   Downloading QDarkStyle-3.2.3-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting QtPy==2.4.3 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 67))
#   Downloading QtPy-2.4.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests==2.32.3 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 68)) (2.32.3)
# Requirement already satisfied: scikit-learn==1.6.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 69)) (1.6.1)
# Collecting scipy==1.15.2 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 70))
#   Downloading scipy-1.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: scooby==0.10.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 71)) (0.10.0)
# Requirement already satisfied: six==1.17.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 72)) (1.17.0)
# Collecting stack-data==0.6.3 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 73))
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: threadpoolctl==3.6.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 74)) (3.6.0)
# Requirement already satisfied: tornado==6.4.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 75)) (6.4.2)
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 76)) (4.67.1)
# Collecting traitlets==5.14.3 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 77))
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: typing_extensions==4.13.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 78)) (4.13.2)
# Requirement already satisfied: tzdata==2025.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 79)) (2025.2)
# Collecting urllib3==2.4.0 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 80))
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: wcwidth==0.2.13 in /usr/local/lib/python3.11/dist-packages (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 81)) (0.2.13)
# Collecting xmltodict==0.14.2 (from -r /content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/requirements.txt (line 82))
#   Downloading xmltodict-0.14.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Downloading appnope-0.1.4-py2.py3-none-any.whl (4.3 kB)
# Downloading asttokens-3.0.0-py3-none-any.whl (26 kB)
# Downloading autoreject-0.4.3-py3-none-any.whl (29 kB)
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading darkdetect-0.8.0-py3-none-any.whl (9.0 kB)
# Downloading debugpy-1.8.14-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 35.4 MB/s eta 0:00:00
# Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Downloading executing-2.2.0-py2.py3-none-any.whl (26 kB)
# Downloading h5io-0.2.5-py3-none-any.whl (17 kB)
# Downloading ipykernel-6.29.5-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 8.0 MB/s eta 0:00:00
# Downloading ipython-8.35.0-py3-none-any.whl (830 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 830.9/830.9 kB 37.6 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 37.6 MB/s eta 0:00:00
# Downloading jupyter_client-8.6.3-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 8.3 MB/s eta 0:00:00
# Downloading llvmlite-0.44.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 12.5 MB/s eta 0:00:00
# Downloading matplotlib-3.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 89.8 MB/s eta 0:00:00
# Downloading mne-1.9.0-py3-none-any.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 62.2 MB/s eta 0:00:00
# Downloading mne_features-0.3-py3-none-any.whl (26 kB)
# Downloading mne_icalabel-0.7.0-py3-none-any.whl (21.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.6/21.6 MB 39.9 MB/s eta 0:00:00
# Downloading mne_qt_browser-0.7.1-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.5/82.5 kB 5.6 MB/s eta 0:00:00
# Downloading numba-0.61.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 69.3 MB/s eta 0:00:00
# Downloading numpy-2.2.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 36.9 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 16.2 MB/s eta 0:00:00
# Downloading pillow-11.2.1-cp311-cp311-manylinux_2_28_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 54.2 MB/s eta 0:00:00
# Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 20.4 MB/s eta 0:00:00
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Downloading pygments-2.19.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.8 MB/s eta 0:00:00
# Downloading pymatreader-1.0.0-py3-none-any.whl (9.3 kB)
# Downloading PyOpenGL_accelerate-3.1.9-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 49.0 MB/s eta 0:00:00
# Downloading PyQt6-6.9.0-cp39-abi3-manylinux_2_28_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 39.0 MB/s eta 0:00:00
# Downloading PyQt6_Qt6-6.9.0-py3-none-manylinux_2_28_x86_64.whl (81.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 MB 6.2 MB/s eta 0:00:00
# Downloading PyQt6_sip-13.10.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.whl (293 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.8/293.8 kB 18.4 MB/s eta 0:00:00
# Downloading pyqtgraph-0.13.7-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 49.0 MB/s eta 0:00:00
# Downloading pyriemann-0.8-py2.py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.7/121.7 kB 4.8 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 8.5 MB/s eta 0:00:00
# Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 24.4 MB/s eta 0:00:00
# Downloading pyzmq-26.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (862 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 862.4/862.4 kB 41.3 MB/s eta 0:00:00
# Downloading QDarkStyle-3.2.3-py2.py3-none-any.whl (871 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.8/871.8 kB 27.4 MB/s eta 0:00:00
# Downloading QtPy-2.4.3-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.0/95.0 kB 5.6 MB/s eta 0:00:00
# Downloading scipy-1.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 9.7 MB/s eta 0:00:00
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 7.0 MB/s eta 0:00:00
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.7/128.7 kB 9.4 MB/s eta 0:00:00
# Downloading xmltodict-0.14.2-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: PyQt6-Qt6, PyOpenGL-accelerate, pure_eval, xmltodict, urllib3, traitlets, QtPy, pyzmq, python-dateutil, PyQt6_sip, Pygments, psutil, pillow, numpy, llvmlite, jedi, executing, exceptiongroup, decorator, debugpy, darkdetect, asttokens, appnope, stack-data, scipy, QDarkStyle, PyWavelets, pyqtgraph, PyQt6, pandas, numba, comm, pymatreader, matplotlib, jupyter_client, ipython, h5io, pyriemann, mne, ipykernel, mne-qt-browser, mne-icalabel, mne-features, autoreject
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.7.1
#     Uninstalling traitlets-5.7.1:
#       Successfully uninstalled traitlets-5.7.1
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 24.0.1
#     Uninstalling pyzmq-24.0.1:
#       Successfully uninstalled pyzmq-24.0.1
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
#       Successfully uninstalled python-dateutil-2.8.2
#   Attempting uninstall: Pygments
#     Found existing installation: Pygments 2.18.0
#     Uninstalling Pygments-2.18.0:
#       Successfully uninstalled Pygments-2.18.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.43.0
#     Uninstalling llvmlite-0.43.0:
#       Successfully uninstalled llvmlite-0.43.0
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
#   Attempting uninstall: debugpy
#     Found existing installation: debugpy 1.8.0
#     Uninstalling debugpy-1.8.0:
#       Successfully uninstalled debugpy-1.8.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.14.1
#     Uninstalling scipy-1.14.1:
#       Successfully uninstalled scipy-1.14.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: numba
#     Found existing installation: numba 0.60.0
#     Uninstalling numba-0.60.0:
#       Successfully uninstalled numba-0.60.0

# %%
import mne
fname = "/content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/50001/EEG/rest"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-af81aa50a83e> in <cell line: 0>()
# ----> 1 import mne
#       2 fname = "/content/drive/MyDrive/Colab Notebooks/TIDE_TEST_DATA/50001/EEG/rest"
#
# ModuleNotFoundError: No module named 'mne'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# %matplotlib qt
fname = "/Users/payamsadeghishabestari/antinomics_clean_codes/subjects/zdfy/EEG/rest_v1/zdfy_rest_v1.vhdr"
sub_dir = "/Users/payamsadeghishabestari/antinomics_clean_codes/subjects/new_style"
preprocess(fname=fname, subject_id="zdfy",
            subjects_dir=sub_dir,
            site="Zuerich",
            paradigm="rest")

# %%
from eeg import preprocessing
preprocessing(subject_id="zdfy",
                subjects_dir="/Users/payamsadeghishabestari/antinomics_clean_codes/subjects",
                paradigm="rest",
                site="Zuerich",
                psd_check=True,
                manual_data_scroll=True,
                run_ica=False,
                manual_ica_removal=False,
                ssp_eog=True,
                ssp_ecg=True,
                create_report=True,
                saving_dir=None,
                verbose="ERROR")

# %%
# %matplotlib qt
from eeg_processing import run_rs_analysis
run_rs_analysis(
        subject_id="zdfy",
        subjects_dir="/Users/payamsadeghishabestari/antinomics_clean_codes/subjects",
        visit=1,
        event_ids=None,
        source_analysis=True,
        mri=False,
        subjects_fs_dir=None,
        manual_data_scroll=True,
        automatic_epoch_rejection=False,
        create_report=True,
        saving_dir=None,
        verbose="ERROR"
        )

# %%
# %matplotlib qt
from eeg_processing import run_erp_analysis
run_erp_analysis(
        subject_id="zdfy",
        subjects_dir="/Users/payamsadeghishabestari/antinomics_clean_codes/subjects",
        paradigm="gpias",
        events=None,
        source_analysis=True,
        mri=False,
        subjects_fs_dir=None,
        manual_data_scroll=True,
        automatic_epoch_rejection=False,
        create_report=True,
        saving_dir=None,
        verbose="ERROR"
        )

# %% [markdown]
# Eyetracking

# %%
from mne.io import read_raw_brainvision, read_raw_eyelink
from mne import events_from_annotations
from mne.preprocessing import realign_raw


## load
fname_eeg = "/Users/payamsadeghishabestari/Downloads/alertness_01_H036.vhdr"
fname_et = "/Users/payamsadeghishabestari/Downloads/local_al1H036.asc"

raw_eeg = read_raw_brainvision(fname_eeg, preload=True)
raw_eye = read_raw_eyelink(fname=fname_et, create_annotations=True)
events_eeg, event_ids_eeg = events_from_annotations(raw_eeg)
events_eye, event_ids_eye = events_from_annotations(raw_eye)

## for now
stim_id_eeg_1, stim_id_eeg_2 = 8, 9
stim_id_eye_1, stim_id_eye_2 = 4, 5

s_raw = events_eeg[(events_eeg[:,2] == stim_id_eeg_1) | (events_eeg[:,2] == stim_id_eeg_2)][:, 0]
s_other = events_eye[(events_eye[:,2] == stim_id_eye_1) | (events_eye[:,2] == stim_id_eye_2)][:, 0]

## realigning
realign_raw(raw=raw_eeg,
            other=raw_eye,
            t_raw=s_raw / raw_eeg.info["sfreq"] - raw_eeg.first_time,
            t_other=s_other / raw_eye.info["sfreq"] - raw_eye.first_time,
            verbose=None)

raw_eye.add_channels([raw_eeg], force_update_info=True)
events, event_dict = events_from_annotations(raw_eye)
del raw_eeg

# %%
raw_eye.plot()

# %% [markdown]
# Lets see what is regularity

# %%
import mne

# %%
fname = "/Users/payamsadeghishabestari/antinomics_clean_codes/subjects/dvob/EEG/regularity/dvob_regularity.vhdr"
raw = mne.io.read_raw_brainvision(fname, preload=True)
raw.resample(250)

# %%
events, events_dict = mne.events_from_annotations(raw)

# %%
import mne
epochs_fnames = ["/Users/payamsadeghishabestari/antinomics_clean_codes/subjects/zdfy/EEG/rest_v1/epochs-eo-epo.fif",
                "/Users/payamsadeghishabestari/antinomics_clean_codes/subjects/zdfy/EEG/rest_v1/epochs-ec-epo.fif"]

epochs, eye_labels = [], []
for ep_fname, title in zip(epochs_fnames, ["open", "close"]):
    eps = mne.read_epochs(ep_fname, preload=True)
    eps.drop_bad()
    epochs.append(eps)
    eye_labels += len(eps) * [title]

# %%
epochs = mne.concatenate_epochs(epochs)

# %%
import numpy as np
import mne_features

# %%
def compute_sensor_band_power(epochs):
    """
    """
    freq_bands = {
                    "delta": (0.5, 4),
                    "theta": (4, 8),
                    "alpha": (8, 13),
                    "beta": (13, 30),
                    "lower_gamma": (30, 45),
                    "upper_gamma": (45, 80)
                    }

    psds, freqs = epochs.compute_psd(method="multitaper",
                                    picks="eeg",
                                    fmin=freq_bands["delta"][0],
                                    fmax=freq_bands["upper_gamma"][1],
                                    ).get_data(return_freqs=True)
    psds /= np.sum(psds, axis=-1, keepdims=True)  # normalize the PSDs
    ep_psds = []
    for fmin, fmax in freq_bands.values():
        psds_band = psds[:, :, (freqs >= fmin) & (freqs < fmax)].mean(axis=-1)
        ep_psds.append(psds_band)


    return np.array(ep_psds).transpose(1, 2, 0)

# %%
freq_bands = {
                "delta": (0.5, 4),
                "theta": (4, 8),
                "alpha": (8, 13),
                "beta": (13, 30),
                "lower_gamma": (30, 45),
                "upper_gamma": (45, 80)
                }



epochs.pick("eeg")
funcs_params = {
                    "pow_freq_bands__freq_bands": freq_bands,
                    "pow_freq_bands__psd_method": "multitaper",
                    "pow_freq_bands__normalize": True
                    }

powers = mne_features.feature_extraction.extract_features(epochs.get_data(),
                                                epochs.info["sfreq"],
                                                selected_funcs=["pow_freq_bands"],
                                                funcs_params=funcs_params,
                                                ch_names=epochs.info["ch_names"]
                                                )

# %%
n_chs = len(epochs.info["ch_names"])
n_freq_bands = len(freq_bands.keys())
powers_reshaped = powers.reshape(len(epochs), n_chs, n_freq_bands)

# %%
columns = [f"ch_{j}_freq_{k}" for j in epochs.info["ch_names"] for k in freq_bands]

# %%
df = pd.DataFrame(powers_reshaped, columns=columns)

# %%
hurst = mne_features.feature_extraction.extract_features(epochs.get_data(),
                                                epochs.info["sfreq"],
                                                selected_funcs=["spect_slope"],
                                                funcs_params=None,
                                                ch_names=epochs.info["ch_names"]
                                                )

# %%
y = hurst.reshape(len(epochs), n_chs, 4)[:,:,:2] # intercept and slope

# %%
y.shape

# %%
x = hurst.reshape(len(epochs), n_chs, 4)[:,:,:2]

# %%
x = x.reshape(257, 118)

# %%
x == hurst[:, :118]

# %%
freq_bands = {
            "delta": (0.5, 4),
            "theta": (4, 8),
            "alpha": (8, 13),
            "beta": (13, 30),
            "lower_gamma": (30, 45),
            "upper_gamma": (45, 80)
            }

psds, freqs = epochs.compute_psd(method="multitaper",
                                    picks="eeg",
                                    fmin=freq_bands["delta"][0],
                                    fmax=freq_bands["upper_gamma"][1],
                                    ).get_data(return_freqs=True)

# %%
psds.shape

# %%
X
